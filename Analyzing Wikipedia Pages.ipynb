# %% [markdown]
# # Analyzing Wikipedia Pages
#
# Preparing for analysis.

# %%
import os

file_names = os.listdir('wiki')
print(len(file_names))

with open(os.path.join('wiki', file_names[0])) as f:
    lines_of_all_files = [line for line in f.readlines()]

for line in lines_of_all_files[:20]:
    print(line)
# Out:
# 999
# <!DOCTYPE html>
#
# <html class="client-nojs" lang="en" dir="ltr">
#
# <head>
#
# <meta charset="UTF-8"/>
#
# <title>Bay of Concepción - Wikipedia</title>
#
# <script>document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );</script>
#
# <script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Bay_of_Concepción","wgTitle":"Bay of Concepción","wgCurRevisionId":647460156,"wgRevisionId":647460156,"wgArticleId":16044270,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Coordinates on Wikidata","All stub articles","Landforms of Bío Bío Region","Bays of Chile","Bío Bío Region geography stubs"],"wgBreakFrames":false,"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgMonthNamesShort":["","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"wgRelevantPageName":"Bay_of_Concepción","wgRelevantArticleId":16044270,"wgRequestId":"WKq3wgpAAEIAAMFPZFwAAABQ","wgIsProbablyEditable":true,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgFlaggedRevsParams":{"tags":{}},"wgStableRevisionId":null,"wgWikiEditorEnabledModules":{"toolbar":true,"dialogs":true,"preview":false,"publish":false},"wgBetaFeaturesFeatures":[],"wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","usePageImages":true,"usePageDescriptions":true},"wgPreferredVariant":"en","wgMFDisplayWikibaseDescriptions":{"search":true,"nearby":true,"watchlist":true,"tagline":true},"wgRelatedArticles":null,"wgRelatedArticlesBetaFeatureEnabled":false,"wgRelatedArticlesUseCirrusSearch":true,"wgRelatedArticlesOnlyUseCirrusSearch":false,"wgULSCurrentAutonym":"English","wgNoticeProject":"wikipedia","wgCentralNoticeCookiesToDelete":[],"wgCentralNoticeCategoriesUsingLegacy":["Fundraising","fundraising"],"wgCategoryTreePageCategoryOptions":"{\"mode\":0,\"hideprefix\":20,\"showcount\":true,\"namespaces\":false}","wgCoordinates":{"lat":-36.683333333333,"lon":-73.033333333333},"wgWikibaseItemId":"Q4874197","wgCentralAuthMobileDomain":false,"wgVisualEditorToolbarScrollOffset":0,"wgEditSubmitButtonLabelPublish":false});mw.loader.state({"ext.globalCssJs.user.styles":"ready","ext.globalCssJs.site.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":"ready","user":"ready","user.options":"loading","user.tokens":"loading","ext.cite.styles":"ready","wikibase.client.init":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready","mediawiki.legacy.shared":"ready","mediawiki.legacy.commonPrint":"ready","mediawiki.sectionAnchor":"ready","mediawiki.skinning.interface":"ready","skins.vector.styles":"ready","ext.globalCssJs.user":"ready","ext.globalCssJs.site":"ready"});mw.loader.implement("user.options@0j3lz3q",function($,jQuery,require,module){mw.user.options.set({"variant":"en"});});mw.loader.implement("user.tokens@1dqfd7l",function ( $, jQuery, require, module ) {
#
# mw.user.tokens.set({"editToken":"+\\","patrolToken":"+\\","watchToken":"+\\","csrfToken":"+\\"});/*@nomin*/;
#
#
#
# });mw.loader.load(["ext.cite.a11y","mediawiki.action.view.postEdit","site","mediawiki.page.startup","mediawiki.user","mediawiki.hidpi","mediawiki.page.ready","mediawiki.legacy.wikibits","mediawiki.searchSuggest","ext.gadget.teahouse","ext.gadget.ReferenceTooltips","ext.gadget.watchlist-notice","ext.gadget.DRN-wizard","ext.gadget.charinsert","ext.gadget.refToolbar","ext.gadget.extra-toolbar-buttons","ext.gadget.switcher","ext.gadget.featured-articles-links","ext.centralauth.centralautologin","mmv.head","mmv.bootstrap.autostart","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging.subscriber","ext.wikimediaEvents","ext.navigationTiming","ext.uls.eventlogger","ext.uls.init","ext.uls.interface","ext.quicksurveys.init","ext.centralNotice.geoIP","ext.centralNotice.startUp","skins.vector.js"]);});</script>
#
# <link rel="stylesheet" href="/w/load.php?debug=false&amp;lang=en&amp;modules=ext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cmediawiki.legacy.commonPrint%2Cshared%7Cmediawiki.sectionAnchor%7Cmediawiki.skinning.interface%7Cskins.vector.styles%7Cwikibase.client.init&amp;only=styles&amp;skin=vector"/>
#
# <script async="" src="/w/load.php?debug=false&amp;lang=en&amp;modules=startup&amp;only=scripts&amp;skin=vector"></script>
#
# <meta name="ResourceLoaderDynamicStyles" content=""/>
#
# <link rel="stylesheet" href="/w/load.php?debug=false&amp;lang=en&amp;modules=site.styles&amp;only=styles&amp;skin=vector"/>
#
# <meta name="generator" content="MediaWiki 1.29.0-wmf.12"/>
#
# <meta name="referrer" content="origin-when-cross-origin"/>
#
# <meta property="og:image" content="https://upload.wikimedia.org/wikipedia/commons/9/9d/Txu-oclc-224571178-sj18-04-quiriquina.jpg"/>
#
# <link rel="alternate" href="android-app://org.wikipedia/http/en.m.wikipedia.org/wiki/Bay_of_Concepci%C3%B3n"/>
#
# <link rel="alternate" type="application/x-wiki" title="Edit this page" href="/w/index.php?title=Bay_of_Concepci%C3%B3n&amp;action=edit"/>
#
# <link rel="edit" title="Edit this page" href="/w/index.php?title=Bay_of_Concepci%C3%B3n&amp;action=edit"/>

# %% [markdown]
# # Adding MapReduce
#
# Count total number of lines in all files with MapReduce.

# %%
import math
import functools
from multiprocessing import Pool

def make_chunks(data, num_chunks):
    chunk_size = math.ceil(len(data) / num_chunks)
    return [data[i:i+chunk_size] for i in range(0, len(data), chunk_size)]

def map_reduce(data, num_processes, mapper, reducer):
    chunks = make_chunks(data, num_processes)
    pool = Pool(num_processes)
    chunk_results = pool.map(mapper, chunks)
    return functools.reduce(reducer, chunk_results)


# Count the total number of lines in all files

folder_name = 'wiki'

def map_total_lines(data):
    total_lines_in_chunk = 0
    for file_name in data:
        with open(os.path.join(folder_name, file_name)) as f:
            lines = [line for line in f.readlines()]
        total_lines_in_chunk += len(lines)
    return total_lines_in_chunk
        
def reduce_total_lines(chunk1, chunk2):
    return chunk1 + chunk2

total_lines = map_reduce(file_names, 4, map_total_lines, reduce_total_lines)
print(total_lines)
# Out:
# 499797

# %% [markdown]
# # Searching for the value with MapReduce
#
# Creating a dictionary where the keys are the file names and the values are lists with all line indexes that contain the given string.

# %%
from functools import partial

def map_reduce(data, num_processes, mapper, reducer, value = None):
    chunks = make_chunks(data, num_processes)
    pool = Pool(num_processes)
    chunk_results = pool.map(partial(mapper, value=value), chunks)
    return functools.reduce(reducer, chunk_results)

# %%
import re

def map_grep(data, value):
    grep_dict = {}
    for file_name in data:
        with open(os.path.join(folder_name, file_name)) as f:
            lines = [line for line in f.readlines()]
#             print(lines)
        for line_index in range(len(lines)):
            if re.search(value, lines[line_index]):
                if file_name not in grep_dict:
                    grep_dict[file_name] = []
                else:
                    grep_dict[file_name].append(line_index)
    return grep_dict

def reduce_grep(dict1, dict2):
    for file_name in dict1:
        if file_name not in dict2:
            dict2[file_name] = dict1[file_name]
        else:
            dict2[file_name] = dict2[file_name] + dict1[file_name]
    return dict2
    
    
grep_dict1 = map_reduce(file_names, 4, map_grep, reduce_grep, 'data')
print(grep_dict1)
# Out:
# {'Saravan_Gilan.html': [58, 60, 70, 74, 127, 847, 850, 852, 901, 984, 1001], 'Agaritine_gammaglutamyltransferase.html': [350, 352, 356, 406, 489, 506], 'Baadj.html': [56, 58, 68, 72, 109, 116, 120, 128, 132, 139, 160, 188, 414, 416, 465, 548, 565], 'George_Ellicott.html': [96, 108, 110, 159, 242, 259], 'Cortile_del_Belvedere.html': [45, 71, 83, 90, 99, 127, 138, 158, 186, 420, 503, 528], 'Mick_Kelly_(Australian_footballer).html': [221, 238], 'Somarasampettai.html': [52, 88, 119, 126, 209, 226, 253], 'PlzeC588_Zoo.html': [44, 48, 95, 158, 160, 209, 292, 317], '2007E2809308_Huddersfield_Town_A.F.C._season.html': [101, 102, 104, 105, 106, 107, 108, 117, 118, 119, 121, 123, 125, 134, 135, 136, 138, 140, 142, 212, 218, 224, 230, 236, 242, 248, 254, 260, 266, 272, 278, 295, 301, 307, 313, 319, 325, 331, 337, 343, 349, 355, 361, 405, 411, 417, 423, 429, 435, 441, 447, 453, 459, 465, 471, 477, 483, 489, 506, 512, 518, 524, 530, 536, 542, 548, 554, 560, 566, 572, 578, 584, 590, 609, 615, 621, 627, 633, 639, 645, 651, 657, 663, 669, 684, 690, 696, 702, 708, 714, 720, 726, 732, 738, 744, 750, 756, 762, 1409, 1425, 1441, 1457, 1473, 1489, 1505, 1521, 1537, 1553, 1569, 1585, 1601, 1617, 1633, 1649, 1665, 1681, 1697, 1713, 1729, 1745, 1761, 1777, 1793, 1809, 1825, 1841, 2351, 2434, 2451], 'David_Jesson.html': [151, 234, 251], 'Nuno_Leal_Maia.html': [92, 94, 135, 143, 226, 251, 278], 'Isaac_GrC3BCnewald.html': [44, 47, 97, 134, 174, 181, 264, 289, 316], 'Battle_of_Wattignies.html': [52, 77, 78, 79, 85, 86, 87, 88, 89, 90, 403, 411, 429, 441, 454, 467, 558, 1039, 1105, 1123, 1152, 1168, 1181, 1195, 1209, 1543, 1581, 1664, 1689], 'SBOA_School_26_Junior_College.html': [44, 47, 58, 61, 226, 400, 483, 500], 'Colchester_Village_Historic_District.html': [64, 74, 112, 264, 265, 273, 275, 324, 407, 432], 'Mohamed_ElSayed.html': [171, 180, 189, 198, 207, 277, 380, 463, 480], 'Hayateumi_Hidehito.html': [468, 485], 'Oliver_Twist_(1912_American_film).html': [286, 335, 418, 435], 'Omar_Onsi.html': [99, 148, 231, 248], 'List_of_people_from_Bangor_Maine.html': [47, 91, 122, 154, 176, 190, 200, 268, 286, 302, 418, 501, 518], 'Bijou_California.html': [44, 57, 59, 69, 97, 99, 148, 231, 248], 'Volume_One_(The_West_Coast_Pop_Art_Experimental_Band_album).html': [109, 223, 306, 323], 'ISMACryp.html': [46, 109, 192, 209], 'Sarah_BlakleyCartwright.html': [47, 58, 113, 196, 213], 'Mirisah.html': [57, 59, 69, 73, 126, 277, 280, 282, 331, 414, 431], 'Bengt_Forsberg.html': [78, 80, 92, 94, 141, 224, 241], 'Irihirose_Station.html': [44, 47, 62, 73, 109, 111, 244, 245, 247, 296, 379, 404], 'A_Month_of_Sundays_(miniseries).html': [46, 171, 254, 271], 'JaromC3ADr_C5A0imr.html': [162, 164, 213, 296, 313], 'Teiji_Ito.html': [160, 198, 205, 288, 305, 332], 'Robert_E._Lee_(FCC).html': [82, 122, 131, 214, 231, 258], 'Giardini_Margherita.html': [45, 56, 58, 60, 103, 186, 211], 'Upper_Beaches.html': [44, 47, 60, 65, 73, 75, 84, 88, 92, 96, 171, 183, 189, 193, 201, 205, 212, 549, 632, 649], 'Minister_of_Foreign_Affairs_(Egypt).html': [242, 250, 333, 358, 385], 'Christine_Gardner.html': [159, 242, 259], 'Roll27s_partridge.html': [68, 118, 120, 169, 252, 277], 'Luciano_Mercante.html': [60, 63, 65, 114, 197, 214], 'Jeff_Boyd.html': [46, 303, 305, 354, 437, 454], 'Abbeville_Sluggers.html': [79, 126, 209, 226], 'East_Down_(Northern_Ireland_Parliament_constituency).html': [44, 97, 103, 116, 1048, 1131, 1148], 'Russian_Cultural_Centre_(Lviv).html': [67, 83, 187, 283, 321, 404, 421], 'Poor_Richard27s_Almanack_(TV_series).html': [175, 224, 307, 324], 'List_of_numberone_singles_of_1993_(Finland).html': [359, 376], 'National_Register_of_Historic_Places_listings_in_Allen_Parish_Louisiana.html': [45, 80, 100, 108, 117, 125, 138, 151, 159, 173, 325, 326, 370, 474, 557, 582], 'Bowie_Race_Track.html': [45, 93, 125, 208, 225], 'Santa_MarC3ADa_YavesC3ADa.html': [51, 55, 149, 151, 153, 202, 285, 302], 'Gemma_Doyle_(politician).html': [220, 303, 320], 'Tommy_Hunter_(baseball).html': [122, 128, 160, 19 ...

# %% [markdown]
# Now improving our map function by making it case insensitive.

# %%
def map_grep_insensitive_case(data, value):
    grep_dict = {}
    for file_name in data:
        with open(os.path.join(folder_name, file_name)) as f:
            lines = [line for line in f.readlines()]
        for line_index in range(len(lines)):
# changing only next line
            if re.search(value.lower(), lines[line_index].lower()):
#                 print(lines[i].lower())
                if file_name not in grep_dict:
                    grep_dict[file_name] = []
                grep_dict[file_name].append(line_index)
    return grep_dict
    
grep_dict2 = map_reduce(file_names, 4, map_grep_insensitive_case, reduce_grep, 'data')
print(grep_dict2)
# Out:
# {'Saravan_Gilan.html': [6, 58, 60, 70, 74, 112, 127, 847, 850, 852, 901, 984, 1001], 'Agaritine_gammaglutamyltransferase.html': [59, 86, 87, 350, 352, 356, 406, 489, 506], 'Baadj.html': [6, 56, 58, 68, 72, 109, 116, 120, 128, 132, 139, 160, 188, 414, 416, 465, 548, 565], 'George_Ellicott.html': [94, 96, 108, 110, 159, 242, 259], 'Cortile_del_Belvedere.html': [6, 45, 71, 83, 90, 99, 127, 138, 158, 186, 420, 503, 528], 'Mick_Kelly_(Australian_footballer).html': [138, 221, 238], 'Somarasampettai.html': [6, 52, 88, 119, 126, 209, 226, 253], 'PlzeC588_Zoo.html': [6, 44, 48, 95, 158, 160, 209, 292, 317], '2007E2809308_Huddersfield_Town_A.F.C._season.html': [100, 101, 102, 104, 105, 106, 107, 108, 117, 118, 119, 121, 123, 125, 134, 135, 136, 138, 140, 142, 212, 218, 224, 230, 236, 242, 248, 254, 260, 266, 272, 278, 295, 301, 307, 313, 319, 325, 331, 337, 343, 349, 355, 361, 405, 411, 417, 423, 429, 435, 441, 447, 453, 459, 465, 471, 477, 483, 489, 506, 512, 518, 524, 530, 536, 542, 548, 554, 560, 566, 572, 578, 584, 590, 609, 615, 621, 627, 633, 639, 645, 651, 657, 663, 669, 684, 690, 696, 702, 708, 714, 720, 726, 732, 738, 744, 750, 756, 762, 1409, 1425, 1441, 1457, 1473, 1489, 1505, 1521, 1537, 1553, 1569, 1585, 1601, 1617, 1633, 1649, 1665, 1681, 1697, 1713, 1729, 1745, 1761, 1777, 1793, 1809, 1825, 1841, 2351, 2434, 2451], 'David_Jesson.html': [82, 151, 234, 251], 'Nuno_Leal_Maia.html': [6, 89, 92, 94, 135, 143, 226, 251, 278], 'Isaac_GrC3BCnewald.html': [6, 44, 47, 97, 134, 174, 181, 264, 289, 316], 'Battle_of_Wattignies.html': [6, 52, 77, 78, 79, 85, 86, 87, 88, 89, 90, 403, 411, 429, 441, 454, 467, 558, 563, 1039, 1105, 1123, 1152, 1168, 1181, 1195, 1209, 1543, 1581, 1664, 1689], 'SBOA_School_26_Junior_College.html': [6, 44, 47, 58, 61, 226, 400, 483, 500], 'Colchester_Village_Historic_District.html': [6, 64, 74, 106, 112, 264, 265, 273, 275, 324, 407, 432], 'Mohamed_ElSayed.html': [47, 171, 180, 189, 198, 207, 277, 380, 463, 480], 'Hayateumi_Hidehito.html': [346, 385, 468, 485], 'Oliver_Twist_(1912_American_film).html': [284, 286, 335, 418, 435], 'Omar_Onsi.html': [97, 99, 148, 231, 248], 'List_of_people_from_Bangor_Maine.html': [44, 47, 91, 122, 154, 176, 190, 200, 268, 286, 302, 361, 362, 363, 364, 366, 371, 372, 418, 501, 518], 'Bijou_California.html': [6, 44, 57, 59, 69, 97, 99, 148, 231, 248], 'Volume_One_(The_West_Coast_Pop_Art_Experimental_Band_album).html': [49, 109, 223, 306, 323], 'ISMACryp.html': [43, 46, 109, 192, 209], 'Sarah_BlakleyCartwright.html': [44, 47, 58, 113, 196, 213], 'Mirisah.html': [6, 57, 59, 69, 73, 111, 126, 277, 280, 282, 331, 414, 431], 'Bengt_Forsberg.html': [69, 78, 80, 92, 94, 141, 224, 241], 'Irihirose_Station.html': [6, 44, 47, 62, 73, 109, 111, 244, 245, 247, 296, 379, 404], 'A_Month_of_Sundays_(miniseries).html': [43, 46, 171, 254, 271], 'JaromC3ADr_C5A0imr.html': [156, 162, 164, 213, 296, 313], 'Teiji_Ito.html': [49, 144, 160, 198, 205, 288, 305, 332], 'Robert_E._Lee_(FCC).html': [80, 82, 122, 131, 214, 231, 258], 'Giardini_Margherita.html': [6, 45, 56, 58, 60, 103, 186, 211], 'Upper_Beaches.html': [6, 44, 47, 60, 65, 73, 75, 84, 88, 92, 96, 171, 183, 189, 193, 201, 205, 212, 549, 632, 649], 'Minister_of_Foreign_Affairs_(Egypt).html': [147, 242, 250, 333, 358, 385], 'Christine_Gardner.html': [115, 159, 242, 259], 'Roll27s_partridge.html': [55, 68, 118, 120, 169, 252, 277], 'Luciano_Mercante.html': [51, 60, 63, 65, 114, 197, 214], 'Jeff_Boyd.html': [43, 46, 303, 305, 354, 437, 454], 'Abbeville_Sluggers.html': [77, 79, 126, 209, 226], 'East_Down_(Northern_Ireland_Parliament_constituency).html': [6, 44, 97, 103, 116, 1048, 1131, 1148], 'Russian_Cultural_Centre_(Lviv).html': [6, 67, 83, 187, 283, 321, 404, 421], 'Poor_Richard27s_Almanack_(TV_series).html': [173, 175, 224, 307, 324], 'List_of_numberone_singles_of_1993_(Finland).html': [276, 359, 376], 'National_Register_of_Historic_Places_listings_in_Allen_Parish_Louisiana.html': [6, 45, 80, 100, 108, 117, 125, 138, 151, 159, 173, 325, 326, 3 ...

# %% [markdown]
# Let's check quantity of values that we found by first and second search.

# %%
def map_count_values(grep_dict1, grep_dict2):
    for file_name in grep_dict2:
        if file_name not in grep_dict1:
            print(f'New matches: {len(grep_dict2[file_name])} in {file_name}')
        elif len(grep_dict2[file_name]) > len(grep_dict1[file_name]):
            print(f'New matches: {len(grep_dict2[file_name]) - len(grep_dict1[file_name])} in {file_name}')

map_count_values(grep_dict1, grep_dict2)
# Out:
# New matches: 2 in Saravan_Gilan.html
# New matches: 3 in Agaritine_gammaglutamyltransferase.html
# New matches: 1 in Baadj.html
# New matches: 1 in George_Ellicott.html
# New matches: 1 in Cortile_del_Belvedere.html
# New matches: 1 in Mick_Kelly_(Australian_footballer).html
# New matches: 1 in Somarasampettai.html
# New matches: 1 in PlzeC588_Zoo.html
# New matches: 1 in 2007E2809308_Huddersfield_Town_A.F.C._season.html
# New matches: 1 in David_Jesson.html
# New matches: 2 in Nuno_Leal_Maia.html
# New matches: 1 in Isaac_GrC3BCnewald.html
# New matches: 2 in Battle_of_Wattignies.html
# New matches: 1 in SBOA_School_26_Junior_College.html
# New matches: 2 in Colchester_Village_Historic_District.html
# New matches: 1 in Mohamed_ElSayed.html
# New matches: 2 in Hayateumi_Hidehito.html
# New matches: 1 in Oliver_Twist_(1912_American_film).html
# New matches: 1 in Omar_Onsi.html
# New matches: 8 in List_of_people_from_Bangor_Maine.html
# New matches: 1 in Bijou_California.html
# New matches: 1 in Volume_One_(The_West_Coast_Pop_Art_Experimental_Band_album).html
# New matches: 1 in ISMACryp.html
# New matches: 1 in Sarah_BlakleyCartwright.html
# New matches: 2 in Mirisah.html
# New matches: 1 in Bengt_Forsberg.html
# New matches: 1 in Irihirose_Station.html
# New matches: 1 in A_Month_of_Sundays_(miniseries).html
# New matches: 1 in JaromC3ADr_C5A0imr.html
# New matches: 2 in Teiji_Ito.html
# New matches: 1 in Robert_E._Lee_(FCC).html
# New matches: 1 in Giardini_Margherita.html
# New matches: 1 in Upper_Beaches.html
# New matches: 1 in Minister_of_Foreign_Affairs_(Egypt).html
# New matches: 1 in Christine_Gardner.html
# New matches: 1 in Roll27s_partridge.html
# New matches: 1 in Luciano_Mercante.html
# New matches: 1 in Jeff_Boyd.html
# New matches: 1 in Abbeville_Sluggers.html
# New matches: 1 in East_Down_(Northern_Ireland_Parliament_constituency).html
# New matches: 1 in Russian_Cultural_Centre_(Lviv).html
# New matches: 1 in Poor_Richard27s_Almanack_(TV_series).html
# New matches: 1 in List_of_numberone_singles_of_1993_(Finland).html
# New matches: 1 in National_Register_of_Historic_Places_listings_in_Allen_Parish_Louisiana.html
# New matches: 1 in Bowie_Race_Track.html
# New matches: 1 in Santa_MarC3ADa_YavesC3ADa.html
# New matches: 1 in Gemma_Doyle_(politician).html
# New matches: 1 in Tommy_Hunter_(baseball).html
# New matches: 1 in Udi_Enugu.html
# New matches: 1 in Roselawn_Indiana.html
# New matches: 1 in Frithjof_Schmidt.html
# New matches: 1 in ARA_Garibaldi.html
# New matches: 1 in Schwobsheim.html
# New matches: 1 in Arrondissements_of_the_Yvelines_department.html
# New matches: 2 in L._Fry.html
# New matches: 1 in Hepatitis_B_virus.html
# New matches: 1 in Jordan_Steel.html
# New matches: 1 in Central_Luzon.html
# New matches: 1 in Jack_Graham_(pastor).html
# New matches: 1 in Teskey_Kyrgyzstan.html
# New matches: 1 in Sentences_(composition).html
# New matches: 2 in Tropical_sprue.html
# New matches: 1 in Elisa_von_der_Recke.html
# New matches: 1 in Neurotica.html
# New matches: 2 in Roxbury_Presbyterian_Church.html
# New matches: 1 in Moosavi_Peace_Formula.html
# New matches: 1 in Fahy_County_Mayo.html
# New matches: 1 in Acrolophus_simulatus.html
# New matches: 1 in Dennis_Chapman.html
# New matches: 2 in Peter_Collingwood.html
# New matches: 5 in List_of_molecular_graphics_systems.html
# New matches: 1 in MOUSE_DHI.html
# New matches: 1 in Hexachaeta_colombiana.html
# New matches: 1 in SC3B8rli.html
# New matches: 1 in Archiepiscopal_Palace_Rouen.html
# New matches: 1 in Oligocentris_deciusalis.html
# New matches: 1 in 2008_Fed_Cup_World_Group_II.html
# New matches: 1 in Camp_Liberty_killings.html
# New matches: 1 in Hemet_Public_Library.html
# New matches: 1 in Omiodes_iridias.html
# New matches: 1 in Goran_ObradoviC487_(footballer_born_1976).html
# New matches: 1 in Shigeo_Kurata.html
# New matches: 1 in Arthur_L._Aidala.html
# New matches: 1 in Clocking_Out_Is_for_Suckers.html
# New matches: 1 in Wilbraham_26_Monson_Academy.html
# New matches: 1 in List_of_gold_medalists_at_2006_South_Asian_Games.html
# New matches: 1 in The_Purpose_Driven_Church.html
# New matches: 1 in Brendan_Foster.html
# New matches: 1 in Glinka_(crater).html
# New matches: 1 in Larry_Brooks.html
# New matches: 1 in Socket_423.html
# New matches: 1 in Double_Wing_Attack.html
# New matches: 1 in Arkansas_Highway_178.html
# New matches: 1 in Taylour_Paige.html
# New matches: 1 in Fraser_Lake_Airport.html
# New matches: 1 in Pedro_Machuca.html
# New matches: 1 in Raymond_II_Count_of_Toulouse.html
# New matches: 1 in Nejat_Alp.html
# New matches: 1 in Checkerspot_(magazine).html
# New matches: 2 in Functoid.html
# New matches: 1 in Roman_Catholic_Diocese_of_Cervia.html
# New matches: 1 in Lopez_v._Davis.html
# New matches: 1 in Coenaculum_secundum.html
# New matches: 1 in Football_at_the_National_Games_of_China.html
# New matches: 1 in Sibling_Revelry.html
# New matches: 1 in 2015E2809316_Washington_Huskies_men27s_basketball_team.html
# New matches: 1 in List_of_birds_of_Malta.html
# New matches: 1 in 2009_English_cricket_season.html
# New matches: 1 in Banovina_of_Croatia.html
# New matches: 1 in Sobolewo_Wysokie_Mazowieckie_County.html
# New matches: 1 in Kentucky_Auditor_election_2011.html
# New matches: 1 in PC582azC3B3wka.html
# New matches: 1 in Anthony_Marten.html
# New matches: 1 in Linowiec_KuyavianPomeranian_Voivodeship.html
# New matches: 1 in Boogie_Bunnies.html
# New matches: 1 in Andrei_Gamalyan.html
# New matches: 1 in Kailas_Pal.html
# New matches: 2 in Vojin_C486etkoviC487.html
# New matches: 1 in Bad_Luck_(Social_Distortion_song).html
# New matches: 1 in Waldoboro_(CDP)_Maine.html
# New matches: 2 in Julien_Boisselier.html
# New matches: 1 in 2014E2809315_Kansas_State_Wildcats_men27s_basketball_team.html
# New matches: 1 in Joint_Social_Welfare_Institute.html
# New matches: 1 in The_Summer_King.html
# New matches: 2 in Jazz_in_Turkey.html
# New matches: 1 in Aleksandra_JagieC582o.html
# New matches: 1 in Luiz_Henrique_Santos.html
# New matches: 3 in Kim_Yonghwa.html
# New matches: 1 in GbiriNiragu_language.html
# New matches: 1 in Yasid.html
# New matches: 1 in 2001_NCAA_Division_I_Field_Hockey_Championship.html
# New matches: 1 in Ctenodes_zonata.html
# New matches: 1 in EDP_Sarichioi_Wind_Farm.html
# New matches: 1 in Coup_d27C3A9tat.html
# New matches: 2 in Holly_Golightly_(comics).html
# New matches: 1 in Johann_Christoph_Hoffbauer.html
# New matches: 1 in Matthew_Liptak.html
# New matches: 1 in Programa_Mejorando_tu_Autoestima.html
# New matches: 1 in Philaeus.html
# New matches: 2 in SalemAuburn_Streets_Historic_District.html
# New matches: 3 in Kate_Harwood.html
# New matches: 1 in Baltic_Peak.html
# New matches: 1 in Laredo_Colombia_Solidarity_Port_of_Entry.html
# New matches: 1 in 104th_Logistic_Support_Brigade_(United_Kingdom).html
# New matches: 1 in Pichoy_Airfield.html
# New matches: 1 in Wreck_Island_Natural_Area_Preserve.html
# New matches: 1 in Desmiphora_bijuba.html
# New matches: 1 in Webb_Dock_railway_line.html
# New matches: 1 in Helena_Nyblom.html
# New matches: 1 in Hall_of_Mental_Cultivation.html
# New matches: 1 in Alpine_skiing_at_the_1994_Winter_Olympics_E28093_Men27s_combined.html
# New matches: 1 in John_Whewell.html
# New matches: 2 in Gulliver_Mickey.html
# New matches: 1 in Henry_Horace_Williams.html
# New matches: 1 in Hebden_Bridge_Picture_House.html
# New matches: 1 in Oued_TlC3A9lat.html
# New matches: 1 in Oldham_Metropolitan_Borough_Council_election_2000.html
# New matches: 1 in Circus_Avenue.html
# New matches: 1 in S27portable_Scoreboards.html
# New matches: 1 in Kettu_Kalyanam.html
# New matches: 1 in Burnin27_Sneakers.html
# New matches: 1 in Union_United_Church.html
# New matches: 1 in Svendborg_SkibsvC3A6rft.html
# New matches: 1 in Campus_of_Texas_A26M_University.html
# New matches: 1 in Bill_Overstreet.html
# New matches: 2 in Urs_Burkart.html
# New matches: 1 in The_K_of_D.html
# New matches: 1 in Gandigwad.html
# New matches: 1 in Kentucky_Theater.html
# New matches: 1 in USS_General_Putnam_(1857).html
# New matches: 1 in George_Jones_(bishop).html
# New matches: 1 in United_Nations_Security_Council_Resolution_1923.html
# New matches: 1 in The_Hackensaw_Boys.html
# New matches: 1 in Harry_Sacksioni.html
# New matches: 1 in David_Beasley.html
# New matches: 1 in Piracy_on_Falcon_Lake.html
# New matches: 1 in Mammoth_Unified_School_District.html
# New matches: 1 in Eggerberg_railway_station.html
# New matches: 1 in Tillandsia_intermedia.html
# New matches: 1 in Town_Yetholm.html
# New matches: 1 in Sparganothis_saracana.html
# New matches: 2 in Smilax_laurifolia.html
# New matches: 2 in Taylor_Williamson.html
# New matches: 1 in Epropetes_metallica.html
# New matches: 1 in Melanolagus_bericoides.html
# New matches: 1 in Arabic_Toilers27_Movement.html
# New matches: 1 in La_Roca_de_la_Sierra.html
# New matches: 1 in Russian_Party_in_Estonia.html
# New matches: 1 in Henry_Louis_Larsen.html
# New matches: 1 in Gardenbased_learning.html
# New matches: 1 in Torovirinae.html
# New matches: 1 in Moses_Hardy.html
# New matches: 1 in Dakar_2_The_World27s_Ultimate_Rally.html
# New matches: 1 in 1896_Indiana_Hoosiers_football_team.html
# New matches: 1 in Els_Dottermans.html
# New matches: 1 in Epichorista.html
# New matches: 1 in Ownership_of_Rangers_F.C..html
# New matches: 1 in Clinton_Engineer_Works.html
# New matches: 1 in The_Showdown_Effect.html
# New matches: 1 in My_Life_(Billy_Joel_song).html
# New matches: 1 in Ramo_Stott.html
# New matches: 1 in Geomancer_(comics).html
# New matches: 1 in Enrique_Morales.html
# New matches: 1 in Enamul_Haque_(cricketer_born_1966).html
# New matches: 1 in Triptolemus_Evrychou.html
# New matches: 2 in Claudia_Neidig.html
# New matches: 1 in Keshav_Ginde.html
# New matches: 1 in Cyclohexane_conformation.html
# New matches: 2 in Dean_Kukan.html
# New matches: 1 in C58CnogC58D_Station.html
# New matches: 1 in List_of_Carboniferous_tetrapods.html
# New matches: 1 in Sol_Orwell.html
# New matches: 1 in Lucius_Allen_(politician).html
# New matches: 1 in Elio_Calderini.html
# New matches: 2 in Demographics_of_American_Samoa.html
# New matches: 1 in Simon27s_Town_railway_station.html
# New matches: 1 in Peringiella_denticulata.html
# New matches: 1 in Arcadio_GonzC3A1lez.html
# New matches: 1 in Watsonville_Junction_California.html
# New matches: 1 in Young_Finnish_Party.html
# New matches: 1 in Venezuelan_referendum_1957.html
# New matches: 1 in BBCHscale_(rice).html
# New matches: 2 in C389cole_des_Mines_de_Douai.html
# New matches: 1 in GalC3A1pagos_Guadalajara.html
# New matches: 1 in Dysgonia_pudica.html
# New matches: 1 in Klaus_Gerwien.html
# New matches: 1 in Lee_Henderson_Watkins.html
# New matches: 1 in Medical_Unit_Selfcontained_Transportable.html
# New matches: 1 in Sabari.html
# New matches: 1 in GoodnightE28093Loving_Trail.html
# New matches: 1 in Heiko_MC3A4rz.html
# New matches: 1 in Timothy_Wanyonyi_Wetangula.html
# New matches: 2 in Frost_Township_Michigan.html
# New matches: 1 in Ivo_Siromahov.html
# New matches: 1 in John_Jephson.html
# New matches: 1 in Clear_Creek_Township_Cooper_County_Missouri.html
# New matches: 1 in Meanings_of_minor_planet_names_440001E28093450000.html
# New matches: 2 in Shabbir_Kumar.html
# New matches: 1 in Sylvia_Moss.html
# New matches: 2 in West_Park_Bridge.html
# New matches: 1 in Crabeating_frog.html
# New matches: 1 in Imperial_amazon.html
# New matches: 1 in 16th_Virginia_Infantry.html
# New matches: 1 in North_Coast_(RTA_Rapid_Transit_station).html
# New matches: 1 in 2004_Tuvalu_ADivision.html
# New matches: 1 in Alex_McEachern.html
# New matches: 1 in Kate_Quarrie.html
# New matches: 1 in Cyclone_Gamede.html
# New matches: 1 in William_McDonald_(Australian_politician).html
# New matches: 1 in Parkgate_railway_station.html
# New matches: 2 in C11orf30.html
# New matches: 1 in Mr_Freedom_(fashion).html
# New matches: 1 in Stade_Municipal_de_Djougou.html
# New matches: 1 in Suwannee_River_Junior_College.html
# New matches: 1 in Estelle_v._Smith.html
# New matches: 1 in 2013_FIA_WTCC_Race_of_Russia.html
# New matches: 1 in Tobi_trousers.html
# New matches: 2 in Old_Mill_Creek_Illinois.html
# New matches: 1 in Museum_of_John_Paul_II_Collection.html
# New matches: 2 in Bahmanabade_Olya.html
# New matches: 1 in Virajpet_(Vidhan_Sabha_constituency).html
# New matches: 1 in USS_Parris_Island_(AG72).html
# New matches: 1 in One_Night_of_Sin.html
# New matches: 1 in Bazemore_Alabama.html
# New matches: 1 in Carthage_Cincinnati.html
# New matches: 2 in Ek_Dil_Sau_Afsane.html
# New matches: 1 in 2005E2809306_in_Welsh_football.html
# New matches: 1 in Pustiu_River.html
# New matches: 1 in Kendalia_Texas.html
# New matches: 1 in Majeepura.html
# New matches: 1 in Zeiraphera.html
# New matches: 1 in Benidorm_Bastards.html
# New matches: 1 in Burmese_shrike.html
# New matches: 1 in FC3A9lix_CC3A1rdenas.html
# New matches: 1 in Axel_Revold.html
# New matches: 1 in 2009_World_Junior_Ice_Hockey_Championships_rosters.html
# New matches: 1 in Qatar_at_the_2013_World_Championships_in_Athletics.html
# New matches: 1 in Nepal_at_the_2008_Summer_Paralympics.html
# New matches: 2 in Daniel_Cerone.html
# New matches: 1 in Alan_Sheehan.html
# New matches: 1 in Work_domain_analysis.html
# New matches: 1 in Pochyta.html
# New matches: 1 in Cygany_Masovian_Voivodeship.html
# New matches: 1 in Larvicide.html
# New matches: 1 in Power_transfer_unit.html
# New matches: 1 in Percy_William_Bunting.html
# New matches: 1 in Chief_Justice_of_New_Zealand.html
# New matches: 1 in KUMT.html
# New matches: 1 in Vanavara_Airport.html
# New matches: 2 in Shoreyjehye_Do.html
# New matches: 1 in Ashley_Wisconsin.html
# New matches: 1 in 55th_parallel_south.html
# New matches: 1 in Curtis_Whitley.html
# New matches: 1 in Post_(structural).html
# New matches: 1 in Lake_Lagunitas.html
# New matches: 2 in Failing_Office_Building.html
# New matches: 1 in Constance_D27Arcy_Mackay.html
# New matches: 1 in Carley_State_Park.html
# New matches: 1 in Puerto_Rico_at_the_2013_World_Aquatics_Championships.html
# New matches: 1 in Eyes_Galaxies.html
# New matches: 1 in Kistenuten.html
# New matches: 1 in Suri_Kerman.html
# New matches: 1 in Children_of_the_Grave.html
# New matches: 1 in Bagrat_VI_of_Georgia.html
# New matches: 2 in Pushkar.html
# New matches: 2 in List_of_Uzbek_films_of_2014.html
# New matches: 2 in KMTZ.html
# New matches: 1 in Football_Foundation.html
# New matches: 1 in Ministry_of_Development_Planning_and_Statistics.html
# New matches: 1 in Caney_Creek_(Matagorda_Bay).html
# New matches: 1 in CecylC3B3wkaBrzC3B3zka.html
# New matches: 1 in Solanum_chilliasense.html
# New matches: 1 in Ballard_Memorial_High_School.html
# New matches: 1 in Thanks_Again.html
# New matches: 1 in The_Land_of_the_Dead.html
# New matches: 1 in Yoshinkan.html
# New matches: 1 in SC3BCderelbe.html
# New matches: 1 in John_Maitland_(Royal_Navy_officer).html
# New matches: 1 in Social_dualism.html
# New matches: 2 in Golabkhvaran.html
# New matches: 1 in Liebig_Peak.html
# New matches: 1 in Garrett_Lucash.html
# New matches: 1 in 1st_Strategic_Aerospace_Division.html
# New matches: 1 in Agnolin.html
# New matches: 2 in CurtissWright_Hangar_(Columbia_South_Carolina).html
# New matches: 1 in Brograve_Mill.html
# New matches: 2 in Blue_SWAT.html
# New matches: 1 in HMS_Stratagem_(P234).html
# New matches: 1 in Pedro_Checa.html
# New matches: 1 in Martha_Herbert.html
# New matches: 1 in Adolf_Schulte.html
# New matches: 2 in Danish_Maritime_Safety_Administration.html
# New matches: 1 in Kiev_Missal.html
# New matches: 2 in Don_Raye.html
# New matches: 1 in Strawberry_foliar_nematode.html
# New matches: 1 in St._Paul_University_Iloilo.html
# New matches: 1 in Roger_Brooke.html
# New matches: 2 in Lis_LC3B8wert.html
# New matches: 2 in Doumanaba.html
# New matches: 1 in H._Larue_Renfroe.html
# New matches: 1 in Crepidula_atrasolea.html
# New matches: 2 in Sahanpur.html
# New matches: 1 in Ksar_Nalut.html
# New matches: 2 in Meleh_Kabude_Sofla.html
# New matches: 1 in Martinus_Hamconius.html
# New matches: 1 in Sanford_Wallace.html
# New matches: 1 in Gratitud.html
# New matches: 1 in PrC3A9liminaires.html
# New matches: 1 in Abraham_Stanyan.html
# New matches: 1 in U.S._Snowboarding_Race_to_the_Cup.html
# New matches: 1 in Seminemacheilus.html
# New matches: 1 in British_Academy_Television_Award_for_Best_Comedy_(Programme_or_Series).html
# New matches: 1 in FC_Bobruisk.html
# New matches: 1 in 2011_UK_Open_Qualifier_4.html
# New matches: 1 in Monarch_Mountain.html
# New matches: 1 in Johnny_B._Moore.html
# New matches: 1 in Ayish_Bayou.html
# New matches: 1 in Newton_Stone.html
# New matches: 1 in Treaty_of_Ryswick.html
# New matches: 1 in Kenneth_van_Kempen.html
# New matches: 1 in Progressive_refinement.html
# New matches: 1 in Zoom_Systems.html
# New matches: 2 in Panchamrutham.html
# New matches: 1 in Hoghiz.html
# New matches: 1 in Peltigera_membranacea.html
# New matches: 1 in Ovum_Recordings.html
# New matches: 1 in XCops_(band).html
# New matches: 1 in Dick_Johnson_(clarinetist).html
# New matches: 1 in New_York_Women_Composers_Inc..html
# New matches: 1 in Urodilatin.html
# New matches: 1 in Stephen_Unwin_(director).html
# New matches: 1 in Columbia_Airport_(Ohio).html
# New matches: 1 in Shibanov.html
# New matches: 1 in Bifidocarpus.html
# New matches: 1 in Priscus_of_Epirus.html
# New matches: 2 in Bibiana_Beglau.html
# New matches: 1 in Ordinary_singularity.html
# New matches: 1 in Castle_of_Cardona.html
# New matches: 1 in Chemin_d27Aylmer.html
# New matches: 1 in Emmanuel_Muhammad.html
# New matches: 1 in Bulbonaricus.html
# New matches: 1 in Kelvin_Mbilinyi.html
# New matches: 1 in Emily_(1964_song).html
# New matches: 1 in Pixley_Township_Clay_County_Illinois.html
# New matches: 1 in Queensland_Music_Festival.html
# New matches: 1 in Liberty_Central_School_District.html
# New matches: 1 in Kamakshyanagar.html
# New matches: 1 in SotC481panna.html
# New matches: 2 in Kattukukke.html
# New matches: 1 in Tischofer_Cave.html
# New matches: 1 in Barren_vegetation.html
# New matches: 1 in USS_Impeccable_(AM320).html
# New matches: 1 in Burbridge_Creek.html
# New matches: 1 in Phil_Spence.html
# New matches: 1 in Ronald_McCaffer.html
# New matches: 1 in Macy_conferences.html
# New matches: 1 in Furubira_District_Hokkaido.html
# New matches: 1 in Dalian_Road_Station.html
# New matches: 1 in Antonio_de_Zayas_(bishop).html
# New matches: 1 in Ramana_Pakistan.html
# New matches: 1 in Hideki_Kase.html
# New matches: 2 in Acceptance_(Heroes).html
# New matches: 1 in RF_microwave_CAE_CAD.html
# New matches: 1 in Ego_Dominus_Tuus.html
# New matches: 1 in High_Efficiency_Image_File_Format.html
# New matches: 1 in ItalyE28093United_States_relations.html
# New matches: 2 in Westchester_Los_Angeles.html
# New matches: 1 in Konstantin_22Samokovetsa22_Dimitrov.html
# New matches: 1 in Jonas_ArC48Dikauskas.html
# New matches: 1 in Lungujja.html
# New matches: 1 in C27est_la_vie_(Khaled_song).html
# New matches: 1 in AlNurayn_Mosque.html
# New matches: 1 in Morten_RutkjC3A6r.html
# New matches: 1 in Government_Polytechnic_Nagriya_Mod_Etah.html
# New matches: 1 in Ma_Sen.html
# New matches: 1 in Phenacobius_catostomus.html
# New matches: 1 in Norderbrarup.html
# New matches: 1 in Octomeria_lithophila.html
# New matches: 1 in Joint_Committee_for_Traceability_in_Laboratory_Medicine.html
# New matches: 1 in Yuga_(film).html
# New matches: 1 in Clay_Research_Award.html
# New matches: 1 in Kreslyuvtsi.html
# New matches: 1 in PanhandleE28093Plains_Historical_Museum.html
# New matches: 1 in 33rd_New_Jersey_Volunteer_Infantry.html
# New matches: 1 in Steinkjersannan.html
# New matches: 1 in Senapati_district.html
# New matches: 1 in The_Wire_(JTFGTMO).html
# New matches: 1 in Chhaparband_(Muslim).html
# New matches: 1 in Guaricana_National_Park.html
# New matches: 1 in Challenger_Banque_Nationale_de_Drummondville.html
# New matches: 2 in Appa_(film).html
# New matches: 1 in Ben_H._Williams.html
# New matches: 1 in Hypocysta_angustata.html
# New matches: 1 in Copenhagen_Skatepark.html
# New matches: 1 in Saratoga_Automobile_Museum.html
# New matches: 1 in Women27s_javelin_throw_world_record_progression.html
# New matches: 1 in Madhuri_Desai.html
# New matches: 1 in Odder.html
# New matches: 1 in Aldona_Orman.html
# New matches: 1 in Vancouver_Furious_George.html
# New matches: 1 in Dextran_1.html
# New matches: 2 in HD_90156.html
# New matches: 1 in C389taule.html
# New matches: 1 in Zhongxing_Guesthouse.html
# New matches: 1 in 1988_State_of_Origin_series.html
# New matches: 1 in Hemiargyropsis_frontalis.html
# New matches: 3 in The_Audacity_to_Podcast.html
# New matches: 1 in I_Q_(book_series).html
# New matches: 1 in List_of_Polish_consorts.html
# New matches: 1 in Third_Saturday_in_October.html
# New matches: 1 in Antipater_of_Thessalonica.html
# New matches: 1 in Santa_Maria_Imbaro.html
# New matches: 1 in Juan_Carlos_PinzC3B3n.html
# New matches: 2 in Brownfield_(software_development).html
# New matches: 1 in George_Joseph_Trapp.html
# New matches: 1 in Russell_Road_(Ontario).html
# New matches: 1 in Maneswar_Brahma.html
# New matches: 1 in Robin_Brooke.html
# New matches: 1 in 100_Greatest_Romanians.html
# New matches: 2 in Boardman_Township_Mahoning_County_Ohio.html
# New matches: 1 in Cristian_Berdeja.html
# New matches: 2 in King_Parker_House.html
# New matches: 1 in DuC5A1anovo.html
# New matches: 1 in John_Shaw_Rennie.html
# New matches: 1 in ThorntonleBeans.html
# New matches: 1 in Meneng_Constituency.html
# New matches: 3 in List_of_Spaghetti_Western_films.html
# New matches: 1 in Paul_Kenny_(politician).html
# New matches: 1 in DWTETV.html
# New matches: 1 in Luca_Luciano.html
# New matches: 1 in Cannabis_in_Spain.html
# New matches: 1 in Roque_PC3A9rez_Partido.html
# New matches: 1 in VSX2.html
# New matches: 1 in Varsity_College.html
# New matches: 1 in Keegan_Pereira_(footballer).html
# New matches: 1 in Eudonia_notozeucta.html
# New matches: 1 in Pirama.html
# New matches: 1 in Shinpei_Matsushita.html
# New matches: 1 in Anton_von_Troeltsch.html
# New matches: 1 in Vang_stone.html
# New matches: 1 in Heinz_Inniger.html
# New matches: 1 in Marion_Rockefeller_Weber.html
# New matches: 1 in Abdulla_Majid_Al_Naimi.html
# New matches: 2 in The_Future_(film).html
# New matches: 1 in Fusinus_carvalhoriosi.html
# New matches: 1 in UtielRequena.html
# New matches: 1 in List_of_Nymphaeales_of_Montana.html
# New matches: 2 in Weiser_River.html
# New matches: 1 in Elzear_Torreggiani.html
# New matches: 1 in Scarlet_wrasse.html
# New matches: 1 in Svinjare.html
# New matches: 1 in St._Peter27s_Church_Tiberias.html
# New matches: 1 in G.O.Y.A._(Gunz_Or_Yay_Available).html
# New matches: 1 in Switzerland_at_the_1992_Winter_Olympics.html
# New matches: 1 in Chef_Wan.html
# New matches: 2 in Jon_Mullich.html
# New matches: 1 in LlwynCus.html
# New matches: 1 in A_Sport_and_a_Pastime.html
# New matches: 1 in The_Right_Kinda_Lover.html
# New matches: 1 in Intel_QuickPath_Interconnect.html
# New matches: 1 in Sierra_Leone_Studies.html
# New matches: 2 in Harry_Hill_Bandholtz.html
# New matches: 1 in Rob_Jones_(footballer_born_1971).html
# New matches: 1 in Abdelwahid_Aboud_Mackaye.html
# New matches: 1 in Equestrian_at_the_1936_Summer_Olympics.html
# New matches: 1 in MarieJosC3A8phe_Jude.html
# New matches: 1 in Pergamus.html
# New matches: 1 in Biorock.html
# New matches: 1 in GewC3A4chshaus_fC3BCr_tropische_Nutzpflanzen.html
# New matches: 1 in De_La_Salle_University_E28093_DasmariC3B1as.html
# New matches: 1 in Antigonadotropin.html
# New matches: 1 in Henrique_da_Silveira.html
# New matches: 1 in Jane_Wrightson.html
# New matches: 1 in Gregory_Fortuin.html
# New matches: 1 in Prisons_in_Bolivia.html
# New matches: 1 in Carte_Imagine27R.html
# New matches: 1 in Paul_Maddrell.html
# New matches: 1 in Vivian_Prokop.html
# New matches: 1 in Paser_Crossword_Stela.html
# New matches: 3 in Shpolskii_matrix.html
# New matches: 1 in Bruce_Conte.html
# New matches: 1 in Giants27_grave_of_S27Ena27e_Thomes.html
# New matches: 1 in TamC3A1s_Buday.html
# New matches: 1 in SC_Goldau.html
# New matches: 1 in Robert_Frederick_Blum.html
# New matches: 1 in SSR180711.html
# New matches: 1 in Sagrai.html
# New matches: 1 in GaC5A1parci.html
# New matches: 1 in FalmanCounty_Acres_Texas.html
# New matches: 1 in Sa_Re_Ga_Ma_Pa_Challenge_USA_2008.html
# New matches: 1 in La_Franja.html
# New matches: 1 in Estadio_Municipal_Pozoblanco.html
# New matches: 1 in 1951_National_League_tiebreaker_series.html
# New matches: 1 in Unionidae.html
# New matches: 1 in WFGIFM.html
# New matches: 1 in Corporation_(university).html
# New matches: 1 in 1910_in_literature.html
# New matches: 1 in Robert_Boehringer.html
# New matches: 1 in Social_impact_of_YouTube.html
# New matches: 1 in FC_Khikhani_Khulo.html
# New matches: 1 in The_Lavender_Cowboy.html
# New matches: 1 in Tomislav_Erceg.html
# New matches: 1 in Meir_Zlotowitz.html
# New matches: 1 in Awali.html
# New matches: 1 in Tongyi_Mingin.html
# New matches: 1 in Gacharageini.html
# New matches: 1 in Fortuna_Glacier.html
# New matches: 7 in Dragnet_(franchise).html
# New matches: 1 in SumbaE28093Flores_languages.html
# New matches: 1 in Ban_On.html
# New matches: 1 in 1915_Montana_football_team.html
# New matches: 1 in DresdenPlauen_railway_station.html
# New matches: 1 in Vijay_Govindarajan.html
# New matches: 1 in Aiva.html
# New matches: 1 in BalC3A1zs_VillC3A1m.html
# New matches: 1 in 2011_Wainwright_Roaming_Buffalo_Classic.html
# New matches: 1 in Uralochka_Zlatoust.html
# New matches: 1 in Smeaton_East_Lothian.html
# New matches: 1 in Sybra_preapicemaculata.html
# New matches: 1 in Papyrus_Oxyrhynchus_56.html
# New matches: 1 in Josh_West.html
# New matches: 1 in Doug_Sahm_and_Band.html
# New matches: 1 in Saladino27s_Inc.html
# New matches: 1 in Hope_7_(album).html
# New matches: 1 in Mykines_Greece.html
# New matches: 2 in Qalat_Kat.html
# New matches: 1 in Woodward_Dream_Cruise.html
# New matches: 1 in USS_Goldcrest.html
# New matches: 1 in Oktyabrsky_District_Russia.html
# New matches: 1 in Aniavan.html
# New matches: 1 in Instrumental.html
# New matches: 1 in Middle_Park_Victoria.html
# New matches: 1 in MarC3ADa_CalderC3B3n.html
# New matches: 1 in Christopher_Speer.html
# New matches: 4 in Maniitsoq_structure.html
# New matches: 2 in Ordinary_Virginia.html
# New matches: 1 in Minardi_M185.html
# New matches: 1 in Millennium_Art_Academy.html
# New matches: 1 in Australian_Musician_(magazine).html
# New matches: 1 in Charlton_baronets.html
# New matches: 1 in Cheddar_Ales.html
# New matches: 2 in Dewoitine_D.21.html
# New matches: 1 in List_of_Bellator_MMA_events.html
# New matches: 1 in Tubular_Bells_II.html
# New matches: 1 in Touch_FM_(Coventry).html
# New matches: 1 in Kadamaha.html
# New matches: 1 in James_L._Hull.html
# New matches: 2 in Furto_di_sera_bel_colpo_si_spera.html
# New matches: 1 in Lin_Chiayu.html
# New matches: 1 in Symeon_Stylites_of_Lesbos.html
# New matches: 1 in I27m_Walking_Behind_You.html
# New matches: 1 in Kellie_Jones.html
# New matches: 1 in Dominique_Voynet.html
# New matches: 1 in Mohammad_Reza_Niknahal.html
# New matches: 1 in Belvedere_London.html
# New matches: 2 in Rudy_The_Rudy_Giuliani_Story.html
# New matches: 1 in Sir_Run_Run_Shaw_Hospital.html
# New matches: 1 in Gaetanus_Matthew_Perez.html
# New matches: 1 in Lydia_VillaKomaroff.html
# New matches: 1 in Sudanese_pound.html
# New matches: 2 in Exploratorium_(film).html
# New matches: 2 in Foulonia.html
# New matches: 1 in Reb_Russell.html
# New matches: 1 in Miltochrista_fuscozonata.html
# New matches: 1 in Luvvie_Darling.html
# New matches: 2 in Amborella.html
# New matches: 1 in List_of_Bratz_episodes.html
# New matches: 1 in Canyamars.html
# New matches: 1 in Kenny_Cordray.html
# New matches: 1 in How_Can_We_Hang_On_to_a_Dream3F.html
# New matches: 1 in Siege_of_Valenciennes_(1793).html
# New matches: 1 in 2016E2809317_New_Zealand_Football_Championship.html
# New matches: 1 in Baddiewinkle.html
# New matches: 1 in David_Solomona.html
# New matches: 2 in Rally_for_Democracy_and_Progress_(Benin).html
# New matches: 1 in 2011E2809312_Western_Collegiate_Hockey_Association_women27s_ice_hockey_season.html
# New matches: 1 in List_of_Argentine_Primera_DivisiC3B3n_transfers_January_2011.html
# New matches: 1 in I_Am_Cold.html
# New matches: 1 in Rubber_Biscuit.html
# New matches: 1 in Heald_Green.html
# New matches: 1 in Charles_Smith_Wilcox.html
# New matches: 2 in Swathi_Chinukulu.html
# New matches: 1 in Noise_(song).html
# New matches: 1 in Maukala.html
# New matches: 1 in Hilyard_Robinson.html
# New matches: 1 in Shellie_Morris.html
# New matches: 1 in Bob_Bass.html
# New matches: 1 in Diphilus_(physician).html
# New matches: 1 in Arun_K._Pati.html
# New matches: 1 in Sky_Regional_Airlines.html
# New matches: 1 in Friendship_Wake_County_North_Carolina.html
# New matches: 1 in Wilhelm_August_Graah.html
# New matches: 1 in Avenira.html
# New matches: 3 in Precorrin6A_reductase.html
# New matches: 1 in Slade_School_of_Fine_Art.html
# New matches: 1 in Zane_Radcliffe.html
# New matches: 1 in Devitt_Insurance.html
# New matches: 1 in Lincoln_Clarkes.html
# New matches: 1 in Havnar_RC3B3C3B0rarfelag.html
# New matches: 1 in Tarsila_do_Amaral.html
# New matches: 1 in Ioana_Badea.html
# New matches: 2 in The_Gentleman_Without_a_Residence_(1915_film).html
# New matches: 1 in Troso_da_Monza.html
# New matches: 1 in Walter_of_Durham.html
# New matches: 1 in James_Wilkes_Maurice.html
# New matches: 1 in Section_20_of_the_Canadian_Charter_of_Rights_and_Freedoms.html
# New matches: 1 in Ferdinand_Mainzer.html
# New matches: 1 in West_Valley_Washington.html
# New matches: 1 in List_of_lakes_in_Independence_County_Arkansas.html
# New matches: 1 in Keeled_sideband.html
# New matches: 1 in Athletics_at_the_1994_Commonwealth_Games_E28093_Men27s_pole_vault.html
# New matches: 1 in Palio_zosterae.html
# New matches: 1 in Turowo_Pomeranian_Voivodeship.html
# New matches: 1 in Nickel(II)_hydroxide.html
# New matches: 1 in Usher_Gahagan.html
# New matches: 1 in Uruguayan_constitutional_referendum_2014.html
# New matches: 1 in John_V._G._Posey_House.html
# New matches: 1 in Kfarhata.html
# New matches: 1 in Second_Valley_South_Australia.html
# New matches: 1 in James_Alexander_Ulio.html
# New matches: 1 in When_You_Loved_Me.html
# New matches: 1 in Flat_roof.html
# New matches: 1 in Jack_Wong.html
# New matches: 2 in Manhattan_Murder_Mystery.html
# New matches: 1 in DiGiorgio_Corporation.html
# New matches: 3 in Viva_Villa.html
# New matches: 1 in Eugenio_Morelli.html
# New matches: 1 in Kenneth_Thomas_(cricketer).html
# New matches: 1 in IwakiIshikawa_Station.html
# New matches: 1 in James_Magee.html
# New matches: 2 in Companys_procC3A9s_a_Catalunya.html
# New matches: 1 in Bill_Price_(baseball).html
# New matches: 1 in Mount_Jim_Crow_National_Park.html
# New matches: 2 in Avengers_Academy.html
# New matches: 1 in Scrobipalpa_halophila.html
# New matches: 1 in Swan_neck_deformity.html
# New matches: 1 in Chhatrasal.html
# New matches: 1 in Macroglossum_pseudoluteata.html
# New matches: 2 in Antibiotic_use_in_livestock.html
# New matches: 1 in Omaha_Racers.html
# New matches: 2 in Syngenor.html
# New matches: 1 in Mrs._Wilkes27_Dining_Room.html
# New matches: 1 in Mecklenburg_Switzerland_and_Lake_Kummerow_Nature_Park.html
# New matches: 1 in List_of_largest_chemical_producers.html
# New matches: 2 in Cobble_Hill_Brooklyn.html
# New matches: 1 in Hannover_Indians.html
# New matches: 1 in Carlos_Martins_(musician).html
# New matches: 1 in Asparuh_Peak.html
# New matches: 1 in Robert_K._Zukowski.html
# New matches: 1 in Gorfion.html
# New matches: 1 in Marson.html
# New matches: 1 in Jens_Pauli_Skaalum.html
# New matches: 1 in Chestnut_pie.html
# New matches: 1 in Vitaly_Bianki.html
# New matches: 1 in Coronium_(gastropod).html
# New matches: 1 in It27s_Just_My_Funny_Way_of_Laughin27.html
# New matches: 1 in Potheri_village_Kanchipuram.html
# New matches: 1 in Arnold_Freiherr_von_Biegeleben.html
# New matches: 1 in Acacia_dermatophylla.html
# New matches: 2 in Typhoon_Hester_(1952).html
# New matches: 2 in WintersWimberley_House.html
# New matches: 1 in Ugo_Okoye.html
# New matches: 2 in Kokan_Colony.html
# New matches: 1 in Naoise_C393_MuirC3AD.html
# New matches: 1 in Turkish_Men27s_Volleyball_Championship.html
# New matches: 1 in Clay_Township_Clark_County_Missouri.html
# New matches: 1 in Redeyed_dove.html
# New matches: 1 in Greg_HalseyBrandt.html
# New matches: 1 in Oleg_Novitskiy.html
# New matches: 1 in Manitoba_general_election_1896.html
# New matches: 2 in Wilhelm_Wagenfeld_House.html
# New matches: 1 in 2014E2809315_Albanian_Third_Division.html
# New matches: 1 in Erigeron_canaani.html
# New matches: 1 in Eternamente_Romanticos.html
# New matches: 1 in Wren_Alabama.html
# New matches: 1 in Lecithocera_sextacta.html
# New matches: 1 in Belgium_women27s_national_field_hockey_team.html
# New matches: 1 in Arthur_Lelyveld.html
# New matches: 1 in Bonny_River.html
# New matches: 1 in Charles_Sears.html
# New matches: 1 in Tonga_national_basketball_team.html
# New matches: 1 in City_of_Mandaluyong_Science_High_School.html
# New matches: 3 in Taipa_HousesE28093Museum.html
# New matches: 1 in Archibald_Gordon_(British_Army_officer).html
# New matches: 1 in Kusaka_Station.html
# New matches: 2 in WLSR.html
# New matches: 1 in Wolfgang_Lutz.html
# New matches: 1 in Curridge.html
# New matches: 1 in Ricard_CardC3BAs.html
# New matches: 1 in I27ve_Heard_That_Song_Before.html
# New matches: 1 in Celebrity_doll.html
# New matches: 1 in Australian_hardcore.html
# New matches: 2 in Lake_County_Examiner.html
# New matches: 1 in HMS_Robust.html
# New matches: 1 in 985_Innovative_Platforms_for_Key_Disciplines_Project.html
# New matches: 1 in Hermann_Nuding.html
# New matches: 1 in Kolound.html
# New matches: 1 in Love_Sax_and_Flashbacks.html
# New matches: 1 in PoznaC584_Wola_railway_station.html
# New matches: 1 in Kanakomyrtus.html
# New matches: 1 in Bulbophyllum_biflorum.html
# New matches: 2 in Copamyntis_infusella.html
# New matches: 1 in Charged_Records.html
# New matches: 1 in 2016E2809317_Little_Rock_Trojans_women27s_basketball_team.html
# New matches: 1 in Cosmopterix_similis.html
# New matches: 1 in Jyoti_Raju.html
# New matches: 1 in Apocephalus_borealis.html
# New matches: 1 in Ready_or_Not_(Young_JV_album).html
# New matches: 1 in Indhiya_Jananayaga_Katchi.html
# New matches: 1 in Bay_of_ConcepciC3B3n.html
# New matches: 1 in Bye_My_Boy.html
# New matches: 1 in Valentin_Yanin.html
# New matches: 1 in Kings_XI_Punjab_in_2014.html
# New matches: 1 in William_Harvey_Lillard.html
# New matches: 1 in Radial_Road_3.html
# New matches: 1 in George_Weldrick.html
# New matches: 1 in Zgornji_Otok.html
# New matches: 1 in Blue_Heelers_(season_8).html
# New matches: 1 in Taggen_Nunatak.html
# New matches: 1 in Henri_BraqueniC3A9.html
# New matches: 1 in Vrila.html
# New matches: 1 in William_Henry_Porter.html
# New matches: 1 in Clive_Brown_(footballer).html
# New matches: 1 in Blick_nach_Rechts.html
# New matches: 1 in Central_District_(Rezvanshahr_County).html
# New matches: 1 in Alexios_Aspietes.html
# New matches: 1 in Mei_Lanfang.html
# New matches: 1 in Wangeroogeclass_tug.html
# New matches: 1 in Dowell_Philip_O27Reilly.html
# New matches: 1 in Coalville_Town_railway_station.html
# New matches: 1 in Gennady_Lesun.html
# New matches: 1 in Bartrum_Glacier.html
# New matches: 1 in Victor_S._Mamatey.html
# New matches: 1 in Gottfried_Keller.html
# New matches: 2 in Table_Point_Formation.html
# New matches: 1 in Nobuhiko_Ushiba.html
# New matches: 1 in Master_of_Space_and_Time.html
# New matches: 1 in Early_medieval_states_in_Kazakhstan.html
# New matches: 1 in Eressa_aperiens.html
# New matches: 1 in Myrtle_(sternwheeler).html
# New matches: 1 in Abanycha_bicolor.html
# New matches: 1 in JeecyVea.html
# New matches: 1 in Aubrey_Fair.html
# New matches: 2 in Ingrid_GuimarC3A3es.html
# New matches: 1 in Urban_chicken.html
# New matches: 1 in Elgin_National_Watch_Company.html
# New matches: 1 in AlMidan.html
# New matches: 1 in Antae_temple.html
# New matches: 1 in Metis_Institute_of_Polytechnic.html
# New matches: 1 in Sverre_Solberg.html
# New matches: 1 in John_Reid_(British_Army_officer).html
# New matches: 1 in List_of_mountains_of_the_Falkland_Islands.html
# New matches: 1 in Fischli.html
# New matches: 1 in Aylon_Darwin_Tavella.html
# New matches: 1 in Sambhaji_Raje_Chhatrapati.html
# New matches: 1 in Alexander_Rizzoni.html
# New matches: 3 in Jules_Verne_ATV.html
# New matches: 1 in Battle_of_Isonzo_(489).html
# New matches: 2 in Pictogram.html
# New matches: 1 in Alan_Oakley.html
# New matches: 1 in Italian_submarine_Comandante_FaC3A0_di_Bruno.html
# New matches: 1 in Le_Premier_Sexe.html
# New matches: 1 in Eugamandus_brunneus.html
# New matches: 1 in Arthur_Norman.html
# New matches: 1 in Feel_No_Fret.html
# New matches: 3 in Claire_Danes.html
# New matches: 1 in Adish_Aggarwala.html
# New matches: 1 in Egg_coffee.html
# New matches: 1 in Diplacus_aurantiacus.html
# New matches: 1 in Justus_Ferdinand_Poggenburg_II.html
# New matches: 1 in Communities_of_Tulu_Nadu.html
# New matches: 1 in Supermoon.html
# New matches: 1 in Ron_Harvey_(rugby_union).html
# New matches: 1 in Meydane_Jahad_Metro_Station.html
# New matches: 1 in Olivaceous_flatbill.html
# New matches: 1 in Javier_Bruses.html
# New matches: 1 in Mitrella_guerreiroi.html
# New matches: 1 in Louis_Vivet.html
# New matches: 1 in Yarkant_County.html
# New matches: 1 in Theonellamide_F.html
# New matches: 2 in PTPRS.html
# New matches: 1 in Promises_Promises_(Incubus_song).html
# New matches: 1 in Legge.html
# New matches: 1 in Tom_Buffington.html
# New matches: 1 in Van_Buren_Ohio.html
# New matches: 1 in Oculorespiratory_syndrome.html
# New matches: 1 in Leuke_Kome.html
# New matches: 1 in The_LoveGirl_and_the_Innocent.html
# New matches: 1 in Horace_Pinker.html
# New matches: 1 in Phong_ThE1BAA1nh_C490C3B4ng_A.html
# New matches: 1 in Kelvin_R._Throop.html
# New matches: 1 in Yemeni_rial.html
# New matches: 1 in Miss_Guatemala_2008.html
# New matches: 1 in Merwin_Hodel.html
# New matches: 2 in A_Beautiful_Valley.html
# New matches: 1 in H._T._Hackney_Company.html
# New matches: 1 in Berzeliustinden.html
# New matches: 1 in John_Nelson_(merchant).html
# New matches: 1 in Short_Message_service_center.html
# New matches: 1 in Lebanon_at_the_1980_Winter_Olympics.html
# New matches: 1 in Streatfeild_family.html
# New matches: 1 in Kendal_Williams.html
# New matches: 1 in Jeff_Weise.html
# New matches: 1 in William_Harper_(South_Carolina).html
# New matches: 1 in Shanghai_Shuffle.html
# New matches: 1 in Danny_Gray.html
# New matches: 1 in Platinum_fulminate.html
# New matches: 1 in Koevtsi_Gabrovo_Province.html
# New matches: 1 in Guyana_at_the_2010_Central_American_and_Caribbean_Games.html
# New matches: 1 in TC58DrC58D_nagashi.html
# New matches: 1 in SC3A3o_SebastiC3A3o_do_Alto.html
# New matches: 1 in Mike_Purdy.html
# New matches: 1 in Hagen_Hauptbahnhof.html
# New matches: 1 in Patrick_F._Philbin.html
# New matches: 1 in Ribboned_sweetlips.html
# New matches: 1 in Endre_Church.html
# New matches: 1 in Nabil_Baha.html
# New matches: 2 in Mudramothiram.html
# New matches: 1 in Schlettau.html
# New matches: 1 in Ameenapuram.html
# New matches: 1 in Nathaniel_Merriman.html
# New matches: 1 in 2011_ITU_Duathlon_World_Championships.html
# New matches: 1 in Mara_Keisling.html
# New matches: 1 in Ragnar_Gustavsson.html
# New matches: 1 in William_de_Pembroke.html
# New matches: 1 in Mark_Maunder.html
# New matches: 1 in Wheatland_High_School_(California).html
# New matches: 1 in Markus_Blutsch.html
# New matches: 1 in Kristiene_Gong.html
# New matches: 1 in Punjab_War.html
# New matches: 1 in Syncretocarpus.html
# New matches: 3 in Gordon_Bau.html
# New matches: 1 in Bibliography_of_Niue.html
# New matches: 2 in Embraer_Unidade_GaviC3A3o_Peixoto_Airport.html
# New matches: 1 in Marv_Felderman.html
# New matches: 4 in Code_page_1023.html
# New matches: 1 in Discretionary_trust.html
# New matches: 1 in Newfoundland_general_election_1848.html
# New matches: 1 in USS_Rose_Mary_(SP1216).html
# New matches: 2 in Cryptographic_primitive.html
# New matches: 2 in Alex_Kurtzman.html
# New matches: 1 in William_Samuel_Viner.html
# New matches: 1 in Nyck_de_Vries.html
# New matches: 1 in ParaC3B1aque_National_High_School_Don_Galo_Annex.html
# New matches: 1 in Scott_McPherson.html
# New matches: 1 in Kirsten_Klein.html
# New matches: 1 in David_Sands_(psychologist).html
# New matches: 1 in Beyond_Magnetic.html
# New matches: 1 in Church_of_the_SubGenius.html
# New matches: 1 in Chapel_of_Mercy_MonacoVille.html
# New matches: 1 in Vaccinium_padifolium.html
# New matches: 1 in ZNF644.html
# New matches: 1 in Regina_Pacis_Catholic_Secondary_School.html
# New matches: 2 in Filip_Pyrochta.html
# New matches: 1 in List_of_women27s_football_clubs_in_Japan.html
# New matches: 1 in Gorgopis_subrimosa.html
# New matches: 1 in Harry_Lynde_Bradley.html
# New matches: 1 in North_Otago_Astronomical_Society_Observatory.html
# New matches: 2 in Morgana_King.html
# New matches: 2 in Don_Parsons_(ice_hockey).html
# New matches: 1 in Evene.html
# New matches: 1 in Therese_Maron.html
# New matches: 1 in Faces_(RunE28093D.M.C._song).html
# New matches: 1 in Burnley_Borough_Council_election_2011.html
# New matches: 1 in CabriniE28093Green_Chicago.html
# New matches: 1 in Plasnewydd.html
# New matches: 1 in 1958_Wightman_Cup.html
# New matches: 2 in Bias.html
# New matches: 1 in Terry_Cox.html
# New matches: 1 in Heo_Mok.html
# New matches: 3 in Tomohiko_ItC58D_(director).html
# New matches: 1 in Maple_Jam_Music_Group.html
# New matches: 1 in Lord_Howe27s_action_or_the_Glorious_First_of_June.html
# New matches: 2 in Imperial_Venus_(film).html
# New matches: 1 in Charles_Stuart_(rugby_union).html
# New matches: 1 in Yarumal.html
# New matches: 1 in Olive_Dennis.html
# New matches: 2 in Camp_Nelson_Confederate_Cemetery.html
# New matches: 1 in Treaty_of_Warsaw_(1970).html
# New matches: 1 in Bill_Widenhouse.html
# New matches: 2 in Benny_Lee.html
# New matches: 1 in 1898_Colgate_football_team.html
# New matches: 1 in Pontefract_byelection_1941.html
# New matches: 1 in Caprinia_versicolor.html
# New matches: 1 in MoneyHunt.html
# New matches: 1 in Neville_Hewitt_(American_football).html
# New matches: 1 in Dialogue_for_Hungary.html
# New matches: 1 in Durham_Women27s_F.C..html
# New matches: 1 in Wu_Jin.html
# New matches: 2 in Kul_Gul.html
# New matches: 1 in Igor_and_Grichka_Bogdanoff.html
# New matches: 1 in Two_House_theology.html
# New matches: 1 in Tramery.html
# New matches: 1 in Revolutionary_Vol._1.html
# New matches: 1 in Gaston_Lane.html
# New matches: 1 in MobiasBanca.html
# New matches: 1 in Hayes_Township_Clay_County_Kansas.html
# New matches: 1 in Lectionary_69.html
# New matches: 1 in Plains_Kansas.html
# New matches: 1 in Arvind_Gokhale.html
# New matches: 1 in Thomas_Croci.html
# New matches: 2 in Medicago_murex.html
# New matches: 1 in Now_That27s_What_I_Call_Music_55_(U.S._series).html
# New matches: 1 in Jazz_at_the_Plaza_Vol._II.html
# New matches: 1 in Josef_Mik.html
# New matches: 1 in Redwater_Mississippi.html
# New matches: 1 in AVM_GmbH.html
# New matches: 1 in 2001_Australian_Individual_Speedway_Championship.html
# New matches: 1 in Mariana_Mazzucato.html
# New matches: 1 in United_Nations_Security_Council_Resolution_731.html
# New matches: 2 in Oldfield_Baby_Great_Lakes.html
# New matches: 1 in Achaea_faber.html
# New matches: 1 in Charles_Page_(cricketer).html
# New matches: 1 in ThalkirchenObersendlingForstenriedFC3BCrstenriedSolln.html
# New matches: 1 in Sweeper.html
# New matches: 1 in Canbelego_County.html
# New matches: 2 in Wilson_Global_Explorer.html
# New matches: 2 in Craig_Chester.html
# New matches: 2 in Derek_Acorah.html
# New matches: 1 in BernardAugustin_Conroy.html
# New matches: 1 in Mountune_Racing.html
# New matches: 1 in AB_v_CD.html
# New matches: 2 in Jack_Goes_Home.html
# New matches: 1 in 2016_Minnesota_Vikings_season.html
# New matches: 2 in Morning_Glory_(2010_film).html
# New matches: 1 in Flashmob_(album).html
# New matches: 1 in I_Marine_Expeditionary_Force.html
# New matches: 1 in KDDQ.html
# New matches: 2 in Tim_Spencer_(singer).html
# New matches: 1 in Liga_de_FC3BAtbol_Profesional_Boliviano.html
# New matches: 1 in Seeking_Gaddafi.html
# New matches: 1 in YC3AAn_BC3A1i.html
# New matches: 1 in Jotedar.html
# New matches: 1 in Kyokutou_I_Love_You.html
# New matches: 1 in The_Portal_(community_center).html
# New matches: 1 in John_C._Freeman_Weather_Museum.html
# New matches: 1 in Mick_Crotty.html
# New matches: 1 in 2010_Karshi_Challenger_E28093_Singles.html
# New matches: 1 in Bluesin27_Around.html
# New matches: 1 in Johnny_Morris_(American_football).html
# New matches: 2 in Lower_Blackburn_Grade_Bridge.html
# New matches: 1 in Rules_of_Engagement_(Alexander_novel).html
# New matches: 1 in The_Wedding_(Sparks_novel).html
# New matches: 1 in TapatC3ADo_hot_sauce.html
# New matches: 1 in 2017_Orange_County_Breakers_season.html
# New matches: 1 in Fureai_kippu.html
# New matches: 1 in Margo_Reuten.html
# New matches: 1 in Land_26_Water_Australia.html
# New matches: 1 in The_Master_Plan_(album).html
# New matches: 2 in 1953E2809354_FA_Cup_qualifying_rounds.html
# New matches: 1 in Mark_Baker_(basketball).html
# New matches: 1 in Zehut.html
# New matches: 2 in Sol_Eclipse.html
# New matches: 2 in Jonathan_A._Goldstein.html
# New matches: 2 in 83_(number).html
# New matches: 2 in Devil_on_Horseback.html
# New matches: 1 in Siuniu.html
# New matches: 1 in Devarampally.html
# New matches: 1 in SolydXK.html

# %% [markdown]
# # Finding Match Positions on Lines
#
# In each pair in dictionary, the first number should be the line index and the second number should be the index on the line (first letter index, where the match starts).
#
# Two ways of implementation:
# * `map_grep_inner_index1`
# example of result:
#
# {
# **'Saravan_Gilan.html': {6: (416, 420), 58: (540, 544)}, 'Agaritine_gammaglutamyltransferase.html': {59: (65, 69), 86: (73, 77)}**
# }
#
# * `map_grep_inner_index2`
# example of result:
#
# {
# **'Saravan_Gilan.html': \[(6, 416), (6, 420), (58, 540), (58, 544)], 'Agaritine_gammaglutamyltransferase.html': [(59, 65), (59, 69), (86, 73)]**
# }

# %%
def map_grep_inner_index1(data, value):
    grep_dict = {}
    for file_name in data:
        with open(os.path.join(folder_name, file_name)) as f:
            lines = [line for line in f.readlines()]
        for line_index in range(len(lines)):
            if re.search(value.lower(), lines[line_index].lower()):
                match = re.search(value.lower(), lines[line_index].lower())
                if file_name not in grep_dict:
                    grep_dict[file_name] = {}
                grep_dict[file_name].update({line_index : match.span()})
    return grep_dict

def reduce_grep(dict1, dict2):
    for file_name in dict1:
        if file_name not in dict2:
            dict2[file_name] = dict1[file_name]
    return dict2
    
    
grep_dict3 = map_reduce(file_names, 4, map_grep_inner_index1, reduce_grep, 'data')
print(grep_dict3)
# Out:
# {'Saravan_Gilan.html': {6: (416, 420), 58: (540, 544), 60: (382, 386), 70: (371, 375), 74: (391, 395), 112: (448, 452), 127: (516, 520), 847: (490, 494), 850: (18, 22), 852: (376, 380), 901: (40, 44), 984: (1007, 1011), 1001: (125, 129)}, 'Agaritine_gammaglutamyltransferase.html': {59: (65, 69), 86: (73, 77), 87: (423, 427), 350: (24, 28), 352: (526, 530), 356: (18, 22), 406: (40, 44), 489: (1091, 1095), 506: (125, 129)}, 'Baadj.html': {6: (486, 490), 56: (563, 567), 58: (378, 382), 68: (353, 357), 72: (409, 413), 109: (398, 402), 116: (426, 430), 120: (338, 342), 128: (333, 337), 132: (404, 408), 139: (338, 342), 160: (491, 495), 188: (366, 370), 414: (18, 22), 416: (486, 490), 465: (40, 44), 548: (971, 975), 565: (125, 129)}, 'George_Ellicott.html': {94: (18, 22), 96: (425, 429), 108: (18, 22), 110: (682, 686), 159: (40, 44), 242: (1011, 1015), 259: (124, 128)}, 'Cortile_del_Belvedere.html': {6: (525, 529), 45: (362, 366), 71: (927, 931), 83: (771, 775), 90: (771, 775), 99: (501, 505), 127: (421, 425), 138: (443, 447), 158: (567, 571), 186: (625, 629), 420: (40, 44), 503: (1035, 1039), 528: (125, 129)}, 'Mick_Kelly_(Australian_footballer).html': {138: (40, 44), 221: (1087, 1091), 238: (124, 128)}, 'Somarasampettai.html': {6: (418, 422), 52: (382, 386), 88: (335, 339), 119: (41, 45), 126: (40, 44), 209: (1011, 1015), 226: (125, 129), 253: (948, 952)}, 'PlzeC588_Zoo.html': {6: (406, 410), 44: (507, 511), 48: (514, 518), 95: (421, 425), 158: (18, 22), 160: (473, 477), 209: (40, 44), 292: (1007, 1011), 317: (125, 129)}, '2007E2809308_Huddersfield_Town_A.F.C._season.html': {100: (474, 478), 101: (250, 254), 102: (430, 434), 104: (460, 464), 105: (253, 257), 106: (447, 451), 107: (251, 255), 108: (471, 475), 117: (474, 478), 118: (252, 256), 119: (430, 434), 121: (460, 464), 123: (447, 451), 125: (471, 475), 134: (474, 478), 135: (252, 256), 136: (430, 434), 138: (460, 464), 140: (447, 451), 142: (471, 475), 212: (468, 472), 218: (468, 472), 224: (519, 523), 230: (468, 472), 236: (468, 472), 242: (468, 472), 248: (468, 472), 254: (468, 472), 260: (468, 472), 266: (468, 472), 272: (483, 487), 278: (528, 532), 295: (468, 472), 301: (468, 472), 307: (468, 472), 313: (468, 472), 319: (468, 472), 325: (519, 523), 331: (468, 472), 337: (468, 472), 343: (519, 523), 349: (468, 472), 355: (468, 472), 361: (468, 472), 405: (468, 472), 411: (468, 472), 417: (519, 523), 423: (468, 472), 429: (468, 472), 435: (468, 472), 441: (468, 472), 447: (468, 472), 453: (468, 472), 459: (468, 472), 465: (468, 472), 471: (483, 487), 477: (468, 472), 483: (528, 532), 489: (468, 472), 506: (468, 472), 512: (468, 472), 518: (468, 472), 524: (468, 472), 530: (519, 523), 536: (468, 472), 542: (468, 472), 548: (519, 523), 554: (468, 472), 560: (468, 472), 566: (468, 472), 572: (477, 481), 578: (468, 472), 584: (468, 472), 590: (468, 472), 609: (456, 460), 615: (441, 445), 621: (501, 505), 627: (441, 445), 633: (492, 496), 639: (441, 445), 645: (441, 445), 651: (441, 445), 657: (450, 454), 663: (441, 445), 669: (441, 445), 684: (465, 469), 690: (441, 445), 696: (492, 496), 702: (441, 445), 708: (465, 469), 714: (441, 445), 720: (441, 445), 726: (492, 496), 732: (441, 445), 738: (492, 496), 744: (441, 445), 750: (441, 445), 756: (441, 445), 762: (441, 445), 1409: (427, 431), 1425: (427, 431), 1441: (442, 446), 1457: (427, 431), 1473: (427, 431), 1489: (427, 431), 1505: (427, 431), 1521: (427, 431), 1537: (427, 431), 1553: (427, 431), 1569: (427, 431), 1585: (442, 446), 1601: (427, 431), 1617: (442, 446), 1633: (472, 476), 1649: (427, 431), 1665: (427, 431), 1681: (427, 431), 1697: (427, 431), 1713: (427, 431), 1729: (427, 431), 1745: (442, 446), 1761: (427, 431), 1777: (427, 431), 1793: (427, 431), 1809: (442, 446), 1825: (427, 431), 1841: (427, 431), 2351: (40, 44), 2434: (1139, 1143), 2451: (124, 128)}, 'David_Jesson.html': {82: (450, 454), 151: (40, 44), 234: (999, 1003), 251: (124, 128)}, 'Nuno_Leal_Maia.html': {6: (491, 495), 89: (162, 166), 92: (18, 22), 94 ...

# %%
def map_grep_inner_index2(data, value):
    grep_dict = {}
    for file_name in data:
        with open(os.path.join(folder_name, file_name)) as f:
            lines = [line for line in f.readlines()]
        for line_index in range(len(lines)):
            if re.search(value.lower(), lines[line_index].lower()):
                if file_name not in grep_dict:
                    grep_dict[file_name] = []
                match = re.search(value.lower(), lines[line_index].lower())
                for m in match.span():
                    grep_dict[file_name].append((line_index, m))
    return grep_dict
    
    
grep_dict4 = map_reduce(file_names, 4, map_grep_inner_index2, reduce_grep, 'data')
print(grep_dict4)
# Out:
# {'Saravan_Gilan.html': [(6, 416), (6, 420), (58, 540), (58, 544), (60, 382), (60, 386), (70, 371), (70, 375), (74, 391), (74, 395), (112, 448), (112, 452), (127, 516), (127, 520), (847, 490), (847, 494), (850, 18), (850, 22), (852, 376), (852, 380), (901, 40), (901, 44), (984, 1007), (984, 1011), (1001, 125), (1001, 129)], 'Agaritine_gammaglutamyltransferase.html': [(59, 65), (59, 69), (86, 73), (86, 77), (87, 423), (87, 427), (350, 24), (350, 28), (352, 526), (352, 530), (356, 18), (356, 22), (406, 40), (406, 44), (489, 1091), (489, 1095), (506, 125), (506, 129)], 'Baadj.html': [(6, 486), (6, 490), (56, 563), (56, 567), (58, 378), (58, 382), (68, 353), (68, 357), (72, 409), (72, 413), (109, 398), (109, 402), (116, 426), (116, 430), (120, 338), (120, 342), (128, 333), (128, 337), (132, 404), (132, 408), (139, 338), (139, 342), (160, 491), (160, 495), (188, 366), (188, 370), (414, 18), (414, 22), (416, 486), (416, 490), (465, 40), (465, 44), (548, 971), (548, 975), (565, 125), (565, 129)], 'George_Ellicott.html': [(94, 18), (94, 22), (96, 425), (96, 429), (108, 18), (108, 22), (110, 682), (110, 686), (159, 40), (159, 44), (242, 1011), (242, 1015), (259, 124), (259, 128)], 'Cortile_del_Belvedere.html': [(6, 525), (6, 529), (45, 362), (45, 366), (71, 927), (71, 931), (83, 771), (83, 775), (90, 771), (90, 775), (99, 501), (99, 505), (127, 421), (127, 425), (138, 443), (138, 447), (158, 567), (158, 571), (186, 625), (186, 629), (420, 40), (420, 44), (503, 1035), (503, 1039), (528, 125), (528, 129)], 'Mick_Kelly_(Australian_footballer).html': [(138, 40), (138, 44), (221, 1087), (221, 1091), (238, 124), (238, 128)], 'Somarasampettai.html': [(6, 418), (6, 422), (52, 382), (52, 386), (88, 335), (88, 339), (119, 41), (119, 45), (126, 40), (126, 44), (209, 1011), (209, 1015), (226, 125), (226, 129), (253, 948), (253, 952)], 'PlzeC588_Zoo.html': [(6, 406), (6, 410), (44, 507), (44, 511), (48, 514), (48, 518), (95, 421), (95, 425), (158, 18), (158, 22), (160, 473), (160, 477), (209, 40), (209, 44), (292, 1007), (292, 1011), (317, 125), (317, 129)], '2007E2809308_Huddersfield_Town_A.F.C._season.html': [(100, 474), (100, 478), (101, 250), (101, 254), (102, 430), (102, 434), (104, 460), (104, 464), (105, 253), (105, 257), (106, 447), (106, 451), (107, 251), (107, 255), (108, 471), (108, 475), (117, 474), (117, 478), (118, 252), (118, 256), (119, 430), (119, 434), (121, 460), (121, 464), (123, 447), (123, 451), (125, 471), (125, 475), (134, 474), (134, 478), (135, 252), (135, 256), (136, 430), (136, 434), (138, 460), (138, 464), (140, 447), (140, 451), (142, 471), (142, 475), (212, 468), (212, 472), (218, 468), (218, 472), (224, 519), (224, 523), (230, 468), (230, 472), (236, 468), (236, 472), (242, 468), (242, 472), (248, 468), (248, 472), (254, 468), (254, 472), (260, 468), (260, 472), (266, 468), (266, 472), (272, 483), (272, 487), (278, 528), (278, 532), (295, 468), (295, 472), (301, 468), (301, 472), (307, 468), (307, 472), (313, 468), (313, 472), (319, 468), (319, 472), (325, 519), (325, 523), (331, 468), (331, 472), (337, 468), (337, 472), (343, 519), (343, 523), (349, 468), (349, 472), (355, 468), (355, 472), (361, 468), (361, 472), (405, 468), (405, 472), (411, 468), (411, 472), (417, 519), (417, 523), (423, 468), (423, 472), (429, 468), (429, 472), (435, 468), (435, 472), (441, 468), (441, 472), (447, 468), (447, 472), (453, 468), (453, 472), (459, 468), (459, 472), (465, 468), (465, 472), (471, 483), (471, 487), (477, 468), (477, 472), (483, 528), (483, 532), (489, 468), (489, 472), (506, 468), (506, 472), (512, 468), (512, 472), (518, 468), (518, 472), (524, 468), (524, 472), (530, 519), (530, 523), (536, 468), (536, 472), (542, 468), (542, 472), (548, 519), (548, 523), (554, 468), (554, 472), (560, 468), (560, 472), (566, 468), (566, 472), (572, 477), (572, 481), (578, 468), (578, 472), (584, 468), (584, 472), (590, 468), (590, 472), (609, 456), (609, 460), (615, 441), (615, 445), (621, 501), (621, 505), (627, 441), (627, 445), (6 ...

# %% [markdown]
# # Displaying the Results
#
# Let's write new map and reduce functions to put the results of grep into a CSV file.

# %%
import csv
import re
import pandas as pd

def map_grep_into_table(data, value):
    chunk_of_matches = []
    for file_name in data:
        #read input csv
        with open(os.path.join(folder_name, file_name)) as f:
            lines = [line.lower() for line in f.readlines()]
            # search for value in each line of each file
            for line_index in range(len(lines)):
                match = re.search(value.lower(), lines[line_index])
                if match:
                    new_line = []
                    new_line.append(file_name)
                    new_line.append(line_index)
                    new_line.append(match.start())

                    context_start = max(match.start() - 30, 0)
                    context_end = match.end() + 31
                    new_line.append(lines[line_index][context_start:context_end])
                    
                    chunk_of_matches.append(new_line)
    return chunk_of_matches                       

def reduce_grep_into_table(list_of_lists1, list_of_lists2):
    grep_results = list_of_lists1 + list_of_lists2
    return grep_results

#open new csv for writing grep results
with open('new_file.csv', 'w', newline='') as new_file:
    header = ['File', 'Line', 'Start index', 'Context']
    writer = csv.writer(new_file)
    writer.writerow(header)
        
    grep_list_of_lists = map_reduce(file_names, 4, map_grep_into_table, reduce_grep_into_table, value = 'science')  
        
    writer.writerows(grep_list_of_lists)

grep_results_df = pd.read_csv('new_file.csv')
print(grep_results_df.head())
# Out:
#                           File  Line  Start index  \
# 0          Valentin_Yanin.html     6          840
# 1          Valentin_Yanin.html    66           90
# 2          Valentin_Yanin.html   144         1440
# 3  William_Harvey_Lillard.html    80          166
# 4       Victor_S._Mamatey.html    48          682
#
#                                              Context
# 0  embers of the ussr academy of sciences","full ...
# 1  href="/wiki/soviet_academy_of_sciences" class=...
# 2  embers_of_the_ussr_academy_of_sciences" title=...
# 3   - palmer, d.d. (1910) <i>the science, art and...
# 4  /franklin_college_of_arts_and_sciences" title=...

# %% [markdown]
# # Conclusion
#
# Now, using the last `map_reduce` function we can find a target word, its context (30 symbols before and after) and its "address", including the file name, the line index and then its starting index in the line.
#
# In this guided project we've implemented a **MapReduce grep algorithm that locates all matches of a given string within all files in a given folder**.
